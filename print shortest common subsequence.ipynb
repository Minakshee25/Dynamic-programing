# %%
# to print LCS using recursion
#User function Template for python3

class Solution:
    t = [[0]*(1001) for i in range(1001)]
    res=''
    def ans(self,x,y,s1,s2):
        if(x==0 or y==0):
            return
        elif(s1[x-1]==s2[y-1]):
            Solution.res=s1[x-1]+Solution.res
            self.ans(x-1,y-1,s1,s2)
            return 
        else:
            if(Solution.t[x-1][y]<Solution.t[x][y-1]):
                self.ans(x,y-1,s1,s2)
            else:
                self.ans(x-1,y,s1,s2)
    def lcs(self,x,y,s1,s2):
        for i in range(1,x+1):
            for j in range(1,y+1):
                if(s1[i-1]==s2[j-1]):
                    Solution.t[i][j] = 1+Solution.t[i-1][j-1]
                else:
                    Solution.t[i][j] = max(Solution.t[i-1][j],Solution.t[i][j-1])
        self.ans(x,y,s1,s2)
        return Solution.res

#{ 
#  Driver Code Starts
#Initial Template for Python 3
import atexit
import io
import sys

# Contributed by : Nagendra Jha

if __name__ == '__main__':
    test_cases = int(input())
    for cases in range(test_cases):
        x,y = map(int,input().strip().split())
        s1 = str(input())
        s2 = str(input())
        ob=Solution()
        print(ob.lcs(x,y,s1,s2))
# } Driver Code Ends

# %%
# to print scs using recursion
#User function Template for python3

class Solution:
    t = [[0]*(1001) for i in range(1001)]
    res=''
    def ans(self,x,y,s1,s2):
        if(x==0 or y==0):
            return
        elif(s1[x-1]==s2[y-1]):
            Solution.res=s1[x-1]+Solution.res
            self.ans(x-1,y-1,s1,s2)
            return 
        else:
            if(Solution.t[x-1][y]<Solution.t[x][y-1]):
                Solution.res=s2[y-1]+Solution.res
                self.ans(x,y-1,s1,s2)
            else:
                Solution.res=s1[x-1]+Solution.res
                self.ans(x-1,y,s1,s2)
    def lcs(self,x,y,s1,s2):
        for i in range(1,x+1):
            for j in range(1,y+1):
                if(s1[i-1]==s2[j-1]):
                    Solution.t[i][j] = 1+Solution.t[i-1][j-1]
                else:
                    Solution.t[i][j] = max(Solution.t[i-1][j],Solution.t[i][j-1])
        self.ans(x,y,s1,s2)
        return Solution.res

#{ 
#  Driver Code Starts
#Initial Template for Python 3
import atexit
import io
import sys

# Contributed by : Nagendra Jha

if __name__ == '__main__':
    test_cases = int(input())
    for cases in range(test_cases):
        x,y = map(int,input().strip().split())
        s1 = str(input())
        s2 = str(input())
        ob=Solution()
        print(ob.lcs(x,y,s1,s2))
# } Driver Code Ends

# %%
# to print scs using while
#User function Template for python3

class Solution:
    t = [[0]*(1001) for i in range(1001)]
    res=''
    def ans(self,x,y,s1,s2):
        i=x
        j=y
        while(i>0 and j>0):
            if(s1[i-1]==s2[j-1]):
                Solution.res=s1[i-1]+ Solution.res
                i-=1
                j-=1
            else:
                if(Solution.t[i-1][j]<Solution.t[i][j-1]):
                    Solution.res=s2[j-1]+Solution.res
                    j-=1
                else:
                    Solution.res=s1[i-1]+Solution.res
                    i-=1
    def lcs(self,x,y,s1,s2):
        for i in range(1,x+1):
            for j in range(1,y+1):
                if(s1[i-1]==s2[j-1]):
                    Solution.t[i][j] = 1+Solution.t[i-1][j-1]
                else:
                    Solution.t[i][j] = max(Solution.t[i-1][j],Solution.t[i][j-1])
        self.ans(x,y,s1,s2)
        return Solution.res

#{ 
#  Driver Code Starts
#Initial Template for Python 3
import atexit
import io
import sys

# Contributed by : Nagendra Jha

if __name__ == '__main__':
    test_cases = int(input())
    for cases in range(test_cases):
        x,y = map(int,input().strip().split())
        s1 = str(input())
        s2 = str(input())
        ob=Solution()
        print(ob.lcs(x,y,s1,s2))
# } Driver Code Ends
